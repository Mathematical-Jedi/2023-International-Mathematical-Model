# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# 设置请求头部信息，模拟浏览器请求
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
# 设置YachtWorld网站上的搜索条件
search_params = {
    'class': 'sail',
    # 'price': 'USD100000-500000',
    # 'length': '40-50ft'
}
base_url = 'https://www.yachtworld.com'

requests.get(base_url, 
    headers=headers)
# Out:
# <Response [200]>

# %% [markdown]
# ## 探索性分析每一个具体url的页面结构

# %%
#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div.boat-details-content > div.details
link = 'https://www.yachtworld.com/yacht/2009-royal-huisman-j-class-yacht-6750313/'
res = requests.get(link, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')
soup.text
# Out:
# 'HANUMAN Racer Royal Huisman for sale - YachtWorld✕YachtWorld AppMake your dream come true todayOpenBoatsPower BoatsSailboatsSell Your BoatPersonal Boat ShopperResearchServicesYacht BrokersBoat DealersSurveyorsYacht LoansInsuranceBoat TransportDirectoryToggle NavigationUnited States (English) ▼ Danmark - Dansk Deutschland - Deutsch Australia - English United Kingdom - English España - Español Suomi - suomi France - Français Italia - Italiano Nederland - Nederlands Norge - Norsk Sverige - SvenskaLogin  CloseBurgess LondonCunard House, London, SW1Y 4LR, United KingdomView phone numberCloseContact the Seller* Please correct highlighted errors.NamePhone (optional)EmailMessageI recently viewed your listing on YachtWorld and I am interested in more details. Thank you.NameContact BrokerHome⁄/Boats for sale⁄/Sail⁄/Racer⁄/Royal Huisman⁄/2009 Royal Huisman J Class Yacht2009 Royal Huisman J Class YachtUS$14,900,000Newport, Rhode Island1/14Image coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soon1 of 14ContactMore from this BrokerShareView 14 PhotosBurgess LondonCunard House, London, SW1Y 4LR, United KingdomView phone numberCloseContact the Seller* Please correct highlighted errors.NamePhone (optional)EmailMessageI recently viewed your listing on YachtWorld and I am interested in more details. Thank you.NameContact Broker2009 Royal Huisman J Class Yacht HANUMAN138ftUS$14,900,000 tax not paidNewport, Rhode IslandBasicsYear2009MakeRoyal HuismanModelJ Class YachtClassRacerLength138.12ftFuel TypeDieselHull MaterialAluminumOffered ByBurgess LondonDescription2009 Royal Huisman J Class YachtBuilt in The Netherlands by Royal Huisman, HANUMAN is one of the most remarkable and highly revered J-Class sailing yachts. HANUMAN has benefited from a vast level of highly customised refits including a complete overhaul of all her racing and sailing systems in advance of the 2017 World Championships. She is "the" J-Class to own and offered for sale with a huge inventory. Her spectacular interior, created by Pieter Beeldsnijder, accommodates up to six guests in 3 en suite cabins, including a full beam owner\'s cabin.Show MoreContact InformationPlease contact Henry Craven-Smith at +44 (0)7796 278 797Other DetailsDisclaimerThe Company offers the details of this vessel in good faith but cannot guarantee or warrant the accuracy of this information nor warrant the condition of the vessel. A buyer should instruct his agents, or his surveyors, to investigate such details as the buyer desires validated. This vessel is offered subject to prior sale, price change, or withdrawal without notice.FeaturesElectrical EquipmentShore Power Inlet✓Generator✓ElectronicsDepthsounder✓Radar✓Log-Speedometer✓Radar Detector✓Wind Speed and Direction✓Computer✓Repeater(s)✓TV Set✓Navigation Center✓Plotter✓DVD Player✓Autopilot✓Radio✓Compas✓GPS✓Cockpit Speakers✓VHF✓Inside EquipmentDishwasher✓Bow Thruster✓Washing Machine✓Electric Bilge Pump✓Oven✓Manual Bilge Pump✓Marine Head✓Air Conditioning✓Electric Head✓Chemical Head✓Hot Water✓Refrigerator✓Fresh Water Maker✓Deep Freezer✓Sea Water Pump✓Battery Charger✓Outside EquipmentTeak Cockpit✓Teak Sidedecks✓Gangway✓Tender✓Liferaft✓Cockpit Cushions✓Swimming Ladder✓RiggingSteering Wheel✓Electric Winch✓Spinnaker Pole✓Hydraulic Winch✓PropulsionEngine MakeScaniaEngine Model350hp Scania DI 12 59M Total Power347.32hpFuel TypeDieselPropeller Type4 BladeSpecificationsDimensionsLength Overall138.12ftLength on Deck137.8ftMax Draft15.49ftBeam21.65ftLength at Waterline90.81ftTanksFresh Water Tank1 x 766.1 gal ()Fuel Tank1 x 2176.78 gal ()Holding Tank()AccommodationsDouble Berths2Twin Berths1Cabins3Heads6Request InformationCallMore yachts from Burgess London2006 Custom Alstom Leroux€62,500,000 (US$67,921,863)West Palm Beach, FloridaBurgess London2017 Mondomarine€47,000,000 (US$51,077,241) ...

# %%
detail = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div.boat-details-content > div.details')
detail.text
# Out:
# 'BasicsYear2009MakeRoyal HuismanModelJ Class YachtClassRacerLength138.12ftFuel TypeDieselHull MaterialAluminumOffered ByBurgess LondonDescription2009 Royal Huisman J Class YachtBuilt in The Netherlands by Royal Huisman, HANUMAN is one of the most remarkable and highly revered J-Class sailing yachts. HANUMAN has benefited from a vast level of highly customised refits including a complete overhaul of all her racing and sailing systems in advance of the 2017 World Championships. She is "the" J-Class to own and offered for sale with a huge inventory. Her spectacular interior, created by Pieter Beeldsnijder, accommodates up to six guests in 3 en suite cabins, including a full beam owner\'s cabin.Show MoreContact InformationPlease contact Henry Craven-Smith at +44 (0)7796 278 797Other DetailsDisclaimerThe Company offers the details of this vessel in good faith but cannot guarantee or warrant the accuracy of this information nor warrant the condition of the vessel. A buyer should instruct his agents, or his surveyors, to investigate such details as the buyer desires validated. This vessel is offered subject to prior sale, price change, or withdrawal without notice.FeaturesElectrical EquipmentShore Power Inlet✓Generator✓ElectronicsDepthsounder✓Radar✓Log-Speedometer✓Radar Detector✓Wind Speed and Direction✓Computer✓Repeater(s)✓TV Set✓Navigation Center✓Plotter✓DVD Player✓Autopilot✓Radio✓Compas✓GPS✓Cockpit Speakers✓VHF✓Inside EquipmentDishwasher✓Bow Thruster✓Washing Machine✓Electric Bilge Pump✓Oven✓Manual Bilge Pump✓Marine Head✓Air Conditioning✓Electric Head✓Chemical Head✓Hot Water✓Refrigerator✓Fresh Water Maker✓Deep Freezer✓Sea Water Pump✓Battery Charger✓Outside EquipmentTeak Cockpit✓Teak Sidedecks✓Gangway✓Tender✓Liferaft✓Cockpit Cushions✓Swimming Ladder✓RiggingSteering Wheel✓Electric Winch✓Spinnaker Pole✓Hydraulic Winch✓PropulsionEngine MakeScaniaEngine Model350hp Scania DI 12 59M Total Power347.32hpFuel TypeDieselPropeller Type4 BladeSpecificationsDimensionsLength Overall138.12ftLength on Deck137.8ftMax Draft15.49ftBeam21.65ftLength at Waterline90.81ftTanksFresh Water Tank1 x 766.1 gal ()Fuel Tank1 x 2176.78 gal ()Holding Tank()AccommodationsDouble Berths2Twin Berths1Cabins3Heads6Request InformationCallMore yachts from Burgess London2006 Custom Alstom Leroux€62,500,000 (US$67,921,863)West Palm Beach, FloridaBurgess London2017 Mondomarine€47,000,000 (US$51,077,241)MonacoBurgess London2009 Royal Huisman J Class YachtUS$14,900,000Newport, Rhode IslandBurgess London2005 Moonen Motor Yacht€4,950,000 (US$5,379,412)Corfu, GreeceBurgess LondonMore from this Broker Visit WebsiteServices'

# %%
items = detail.select('div.header')
len(items)
items[0].text
items[0].next_sibling
for i in range(len(items)):
    if items[i].text.lower()=='specifications':
        break
i
# items[i].text
# Out:
# 6

# %%
def kv_attributes(basic, name='Basic'):
    titles = [f'{name}.{"".join(map(lambda x:x.capitalize(),t.text.strip().split()))}' for t in basic.select('td.datatable-title')]
    values = [t.text.strip() for t in basic.select('td.datatable-value')]
    return {k:v for k,v in zip(titles, values)}
kv_attributes(items[0].next_sibling)
# Out:
# {'Basic.Year': '2009',
#  'Basic.Make': 'Royal Huisman',
#  'Basic.Model': 'J Class Yacht',
#  'Basic.Class': 'Racer',
#  'Basic.Length': '138.12ft',
#  'Basic.FuelType': 'Diesel',
#  'Basic.HullMaterial': 'Aluminum',
#  'Basic.OfferedBy': 'Burgess London'}

# %%
def specification_attributes(specification, name='Specification'):
    sub_categories = specification.select('div.datatable-category')
    titles = []
    values = []
    for category in sub_categories:
        cate_name = category.find(attrs='sub-title').text
        cate_name = ''.join(map(lambda x:x.capitalize(), cate_name.split()))
        titles += [f'{name}.{cate_name}.{"".join(map(lambda x:x.capitalize(),t.text.strip().split()))}' for t in category.select('td.datatable-title')]
        values += [t.text.strip() for t in category.select('td.datatable-value')]
    return {k:v for k,v in zip(titles, values)}
specification_attributes(items[4].next_sibling, 'Features')
# Out:
# {'Features.ElectricalEquipment.ShorePowerInlet': '✓',
#  'Features.ElectricalEquipment.Generator': '✓',
#  'Features.Electronics.Depthsounder': '✓',
#  'Features.Electronics.Radar': '✓',
#  'Features.Electronics.Log-speedometer': '✓',
#  'Features.Electronics.RadarDetector': '✓',
#  'Features.Electronics.WindSpeedAndDirection': '✓',
#  'Features.Electronics.Computer': '✓',
#  'Features.Electronics.Repeater(s)': '✓',
#  'Features.Electronics.TvSet': '✓',
#  'Features.Electronics.NavigationCenter': '✓',
#  'Features.Electronics.Plotter': '✓',
#  'Features.Electronics.DvdPlayer': '✓',
#  'Features.Electronics.Autopilot': '✓',
#  'Features.Electronics.Radio': '✓',
#  'Features.Electronics.Compas': '✓',
#  'Features.Electronics.Gps': '✓',
#  'Features.Electronics.CockpitSpeakers': '✓',
#  'Features.Electronics.Vhf': '✓',
#  'Features.InsideEquipment.Dishwasher': '✓',
#  'Features.InsideEquipment.BowThruster': '✓',
#  'Features.InsideEquipment.WashingMachine': '✓',
#  'Features.InsideEquipment.ElectricBilgePump': '✓',
#  'Features.InsideEquipment.Oven': '✓',
#  'Features.InsideEquipment.ManualBilgePump': '✓',
#  'Features.InsideEquipment.MarineHead': '✓',
#  'Features.InsideEquipment.AirConditioning': '✓',
#  'Features.InsideEquipment.ElectricHead': '✓',
#  'Features.InsideEquipment.ChemicalHead': '✓',
#  'Features.InsideEquipment.HotWater': '✓',
#  'Features.InsideEquipment.Refrigerator': '✓',
#  'Features.InsideEquipment.FreshWaterMaker': '✓',
#  'Features.InsideEquipment.DeepFreezer': '✓',
#  'Features.InsideEquipment.SeaWaterPump': '✓',
#  'Features.InsideEquipment.BatteryCharger': '✓',
#  'Features.OutsideEquipment.TeakCockpit': '✓',
#  'Features.OutsideEquipment.TeakSidedecks': '✓',
#  'Features.OutsideEquipment.Gangway': '✓',
#  'Features.OutsideEquipment.Tender': '✓',
#  'Features.OutsideEquipment.Liferaft': '✓',
#  'Features.OutsideEquipment.CockpitCushions': '✓',
#  'Features.OutsideEquipment.SwimmingLadder': '✓',
#  'Features.Rigging.SteeringWheel': '✓',
#  'Features.Rigging.ElectricWinch': '✓',
#  'Features.Rigging.SpinnakerPole': '✓',
#  'Features.Rigging.HydraulicWinch': '✓'}

# %%
def get_price(soup):

    price = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div > div.summary > div > span.payment-total')

    # price.text.strip().split('$')[1]
    x = float("".join(list(filter(str.isdigit,price.text.split('US$')[1]))))
    return x
get_price(soup)
# Out:
# 14900000.0

# %%
sn = requests.Session()

# %%
# 爬取所有帆船的year属性和价格数据，并将它们存储到CSV文件中
import warnings


def get_yacht_data(url):
    # res = requests.get(url, headers=headers)
    res = sn.get(url, headers=headers)
    return get_yacht_data_req_res(res)
    
def get_yacht_data_req_res(req_res):
    soup = BeautifulSoup(req_res.text, 'html.parser')
    detail = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div.boat-details-content > div.details')
    assert detail is not None
    items = detail.select('div.header')
    assert len(items)>0
    result = {}
    for i, item in enumerate(items):
            if item.text.lower()=='BASICS'.lower() or item.text.lower()=='PROPULSION'.lower():
                result.update(kv_attributes(items[i].next_sibling, name=item.text.lower().capitalize()))
            elif item.text.lower()=='SPECIFICATIONS'.lower() or item.text.lower()=='FEATURES'.lower():
                result.update(specification_attributes(items[i].next_sibling, name=item.text.lower().capitalize()))
    try:
        result['Price'] = get_price(soup)
    except Exception as e:
        # warnings.warn(f"no price for {url}")
        pass
    return result
    
get_yacht_data(link)
# Out:
# {'Basics.Year': '2009',
#  'Basics.Make': 'Royal Huisman',
#  'Basics.Model': 'J Class Yacht',
#  'Basics.Class': 'Racer',
#  'Basics.Length': '138.12ft',
#  'Basics.FuelType': 'Diesel',
#  'Basics.HullMaterial': 'Aluminum',
#  'Basics.OfferedBy': 'Burgess London',
#  'Features.ElectricalEquipment.ShorePowerInlet': '✓',
#  'Features.ElectricalEquipment.Generator': '✓',
#  'Features.Electronics.Depthsounder': '✓',
#  'Features.Electronics.Radar': '✓',
#  'Features.Electronics.Log-speedometer': '✓',
#  'Features.Electronics.RadarDetector': '✓',
#  'Features.Electronics.WindSpeedAndDirection': '✓',
#  'Features.Electronics.Computer': '✓',
#  'Features.Electronics.Repeater(s)': '✓',
#  'Features.Electronics.TvSet': '✓',
#  'Features.Electronics.NavigationCenter': '✓',
#  'Features.Electronics.Plotter': '✓',
#  'Features.Electronics.DvdPlayer': '✓',
#  'Features.Electronics.Autopilot': '✓',
#  'Features.Electronics.Radio': '✓',
#  'Features.Electronics.Compas': '✓',
#  'Features.Electronics.Gps': '✓',
#  'Features.Electronics.CockpitSpeakers': '✓',
#  'Features.Electronics.Vhf': '✓',
#  'Features.InsideEquipment.Dishwasher': '✓',
#  'Features.InsideEquipment.BowThruster': '✓',
#  'Features.InsideEquipment.WashingMachine': '✓',
#  'Features.InsideEquipment.ElectricBilgePump': '✓',
#  'Features.InsideEquipment.Oven': '✓',
#  'Features.InsideEquipment.ManualBilgePump': '✓',
#  'Features.InsideEquipment.MarineHead': '✓',
#  'Features.InsideEquipment.AirConditioning': '✓',
#  'Features.InsideEquipment.ElectricHead': '✓',
#  'Features.InsideEquipment.ChemicalHead': '✓',
#  'Features.InsideEquipment.HotWater': '✓',
#  'Features.InsideEquipment.Refrigerator': '✓',
#  'Features.InsideEquipment.FreshWaterMaker': '✓',
#  'Features.InsideEquipment.DeepFreezer': '✓',
#  'Features.InsideEquipment.SeaWaterPump': '✓',
#  'Features.InsideEquipment.BatteryCharger': '✓',
#  'Features.OutsideEquipment.TeakCockpit': '✓',
#  'Features.OutsideEquipment.TeakSidedecks': '✓',
#  'Features.OutsideEquipment.Gangway': '✓',
#  'Features.OutsideEquipment.Tender': '✓',
#  'Features.OutsideEquipment.Liferaft': '✓',
#  'Features.OutsideEquipment.CockpitCushions': '✓',
#  'Features.OutsideEquipment.SwimmingLadder': '✓',
#  'Features.Rigging.SteeringWheel': '✓',
#  'Features.Rigging.ElectricWinch': '✓',
#  'Features.Rigging.SpinnakerPole': '✓',
#  'Features.Rigging.HydraulicWinch': '✓',
#  'Propulsion.EngineMake': 'Scania',
#  'Propulsion.EngineModel': '350hp Scania DI 12 59M',
#  'Propulsion.TotalPower': '347.32hp',
#  'Propulsion.FuelType': 'Diesel',
#  'Propulsion.PropellerType': '4 Blade',
#  'Specifications.Dimensions.LengthOverall': '138.12ft',
#  'Specifications.Dimensions.LengthOnDeck': '137.8ft',
#  'Specifications.Dimensions.MaxDraft': '15.49ft',
#  'Specifications.Dimensions.Beam': '21.65ft',
#  'Specifications.Dimensions.LengthAtWaterline': '90.81ft',
#  'Specifications.Tanks.FreshWaterTank': '1 x 766.1 gal ()',
#  'Specifications.Tanks.FuelTank': '1 x 2176.78 gal ()',
#  'Specifications.Tanks.HoldingTank': '()',
#  'Specifications.Accommodations.DoubleBerths': '2',
#  'Specifications.Accommodations.TwinBerths': '1',
#  'Specifications.Accommodations.Cabins': '3',
#  'Specifications.Accommodations.Heads': '6',
#  'Price': 14900000.0}

# %%
with open('old_links.txt', 'r') as f:
    links = f.read().split()
links[:5]
# Out:
# ['https://www.yachtworld.com/yacht/2021-sunreef-60-sail-8672222/',
#  'https://www.yachtworld.com/yacht/1979-orion-sparkman-$-stephens-sloop-8474326/',
#  'https://www.yachtworld.com/yacht/1981-baltic-42-dp-8381625/',
#  'https://www.yachtworld.com/yacht/2023-jeanneau-sun-odyssey-349-7835504/',
#  'https://www.yachtworld.com/yacht/2014-schock-harbor-25-8432704/']

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import numpy as np
from tqdm import tqdm
yacht_data_list = list(range(len(links)))
error_list = {}
def set_data(i):
    # print(i)
    try:
        yacht_data_list[i] = get_yacht_data(links[i])
    except Exception as e:
        time.sleep(60)
        try:
            yacht_data_list[i] = get_yacht_data(links[i])
        except:
            error_list[i]=e
            warnings.warn(f"error for {i}: {e}")
        else:
            error_list.pop(i, None)
    else:
        error_list.pop(i, None)

# %%
# with ThreadPoolExecutor(max_workers=64) as t:
with ThreadPoolExecutor(max_workers=32) as t:
    tasks = [t.submit(set_data, i) for i in range(len(links))]
    # tasks = [t.submit(set_data, i) for i in np.random.choice(len(links), 64, replace=False)]
    # tasks = [t.submit(set_data, i) for i in range(64)]
    for future in tqdm(as_completed(tasks), total=len(tasks)):
        pass
# Out:
#  14%|█▎        | 1367/9975 [05:04<41:11,  3.48it/s] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1392:
#   warnings.warn(f"error for {i}: {e}")
#  14%|█▎        | 1368/9975 [06:09<37:00:54, 15.48s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1396:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1397:
#   warnings.warn(f"error for {i}: {e}")
#  14%|█▎        | 1370/9975 [06:09<22:06:25,  9.25s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1384:
#   warnings.warn(f"error for {i}: {e}")
#  14%|█▎        | 1371/9975 [06:09<17:13:37,  7.21s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1390:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1398:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1395:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1383:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1394:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1404:
#   warnings.warn(f"error for {i}: {e}")
#  14%|█▍        | 1377/9975 [07:14<22:53:54,  9.59s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1399:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1405:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1406:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1402:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1400:
#   warnings.warn(f"error for {i}: {e}")
#  14%|█▍        | 1382/9975 [07:14<12:52:22,  5.39s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1403:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1401:
#   warnings.warn(f"error for {i}: {e}")
#  14%|█▍        | 1384/9975 [07:15<10:23:18,  4.35s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 1407:
#   warnings.warn(f"error for {i}: {e}")
#  21%|██        | 2088/9975 [09:04<42:38,  3.08it/s]   C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2114:
#   warnings.warn(f"error for {i}: {e}")
#  21%|██        | 2089/9975 [10:15<28:53:12, 13.19s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2119:
#   warnings.warn(f"error for {i}: {e}")
#  21%|██        | 2090/9975 [10:15<23:02:20, 10.52s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2118:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2115:
#   warnings.warn(f"error for {i}: {e}")
#  21%|██        | 2091/9975 [10:16<17:55:08,  8.18s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2113:
#   warnings.warn(f"error for {i}: {e}")
#  21%|██        | 2093/9975 [10:16<11:02:57,  5.05s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2116:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2108:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2111:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2112:
#   warnings.warn(f"error for {i}: {e}")
#  28%|██▊       | 2801/9975 [12:02<49:19,  2.42it/s]   C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2813:
#   warnings.warn(f"error for {i}: {e}")
#  28%|██▊       | 2802/9975 [13:08<34:55:29, 17.53s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2829:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2831:
#   warnings.warn(f"error for {i}: {e}")
#  28%|██▊       | 2803/9975 [13:08<25:38:05, 12.87s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2832:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2820:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2824:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2827:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2825:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2821:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2837:
#   warnings.warn(f"error for {i}: {e}")
#  28%|██▊       | 2811/9975 [14:23<20:18:55, 10.21s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2836:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2840:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2838:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2841:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2833:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2839:
#   warnings.warn(f"error for {i}: {e}")
#  28%|██▊       | 2817/9975 [14:24<11:18:46,  5.69s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2835:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2834:
#   warnings.warn(f"error for {i}: {e}")
#  34%|███▎      | 3364/9975 [15:49<14:17,  7.71it/s]   C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 2912:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4293/9975 [17:59<19:48,  4.78it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4207:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4294/9975 [18:46<16:34:40, 10.51s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4321:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4295/9975 [18:59<17:29:09, 11.08s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4316:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4318:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4297/9975 [18:59<10:25:28,  6.61s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4320:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4323:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4299/9975 [18:59<6:38:45,  4.22s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4319:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4299/9975 [19:11<6:38:45,  4.22s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4324:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4301/9975 [19:11<7:37:23,  4.84s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4314:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4302/9975 [19:16<7:48:03,  4.95s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4325:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4303/9975 [19:47<16:30:56, 10.48s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4328:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4304/9975 [20:01<17:56:14, 11.39s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4326:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4305/9975 [20:02<13:44:37,  8.73s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4331:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4306/9975 [20:02<10:11:51,  6.48s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4330:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4307/9975 [20:02<7:27:20,  4.74s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4329:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4308/9975 [20:03<5:51:52,  3.73s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4327:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4359/9975 [20:54<3:05:12,  1.98s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4334:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▍     | 4375/9975 [21:17<37:55,  2.46it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4337:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▍     | 4376/9975 [21:17<35:02,  2.66it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4339:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▍     | 4378/9975 [21:17<21:53,  4.26it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4336:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4338:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▍     | 4412/9975 [21:24<15:32,  5.97it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4340:
#   warnings.warn(f"error for {i}: {e}")
#  45%|████▌     | 4495/9975 [21:36<15:24,  5.93it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 4335:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5774/9975 [24:52<11:50,  5.91it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5795:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5775/9975 [25:52<13:39:46, 11.71s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5798:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5799:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5776/9975 [25:52<10:44:49,  9.21s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5804:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5778/9975 [25:52<6:41:45,  5.74s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5801:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5779/9975 [26:08<9:17:01,  7.97s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5805:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5800:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5781/9975 [26:08<5:47:38,  4.97s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5803:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5782/9975 [26:09<4:35:23,  3.94s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5802:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 15: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1998-catalina-34-mkii-8651102/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5784/9975 [26:37<9:10:59,  7.89s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 16: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2000-hunter-26-8428645/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5785/9975 [26:38<7:17:22,  6.26s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 19: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2006-beneteau-343-8250854/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5786/9975 [26:38<5:40:25,  4.88s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1993-hunter-30-8367272/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5787/9975 [26:38<4:18:48,  3.71s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 29: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2023-jeanneau-yacht-51-8230142/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 11: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1977-hardin-offshore-8092226/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 43: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1999-meta-custom-joubert-motorsailor-8559750/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5790/9975 [26:38<2:07:59,  1.84s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 33: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2018-jeanneau-58-8381607/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 73: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2022-bavaria-c45-8749145/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5792/9975 [26:39<1:28:49,  1.27s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 42: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2001-island-packet-350-8555647/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5793/9975 [26:39<1:20:30,  1.15s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 78: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1981-sabre-34-mark-i-8651572/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5794/9975 [26:39<1:05:03,  1.07it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 34: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2008-jeanneau-sun-odyssey-39i-8417208/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5795/9975 [26:40<52:03,  1.34it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 35: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2017-beneteau-oceanis-60-8278407/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 44: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1987-pearson-31-2-8491553/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5797/9975 [26:40<36:19,  1.92it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 79: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2020-jeanneau-sun-odyssey-410-8733887/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5798/9975 [26:40<35:45,  1.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 85: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1978-c$c-36-8386793/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5799/9975 [26:41<37:17,  1.87it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 62: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2014-hunter-33-8595959/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5800/9975 [26:42<50:34,  1.38it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 89: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2020-compass-sea-compass-82-8604200/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5801/9975 [26:43<46:22,  1.50it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 63: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1983-beneteau-first-38.5-8225109/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5802/9975 [26:43<41:29,  1.68it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 92: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2011-jeanneau-44i-8626029/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5803/9975 [26:44<46:17,  1.50it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 112: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/1946-sparkman-$-stephens-33-pilot-sloop-8374876/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5804/9975 [26:46<1:19:20,  1.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5806:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5805/9975 [26:52<2:51:12,  2.46s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5809:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5806/9975 [26:53<2:11:57,  1.90s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5807:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5807/9975 [26:54<2:12:49,  1.91s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5808:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5808/9975 [26:55<1:53:35,  1.64s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5811:
#   warnings.warn(f"error for {i}: {e}")
#  58%|█████▊    | 5809/9975 [27:10<6:13:41,  5.38s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5813:
#   warnings.warn(f"error for {i}: {e}")
#  60%|█████▉    | 5969/9975 [27:54<11:43,  5.70it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5818:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5819:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5816:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5817:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5815:
#   warnings.warn(f"error for {i}: {e}")
#  60%|█████▉    | 5975/9975 [27:54<05:34, 11.97it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5820:
#   warnings.warn(f"error for {i}: {e}")
#  60%|██████    | 5996/9975 [27:57<07:50,  8.46it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 5836:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7342/9975 [31:02<10:41,  4.10it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7367:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7343/9975 [32:01<7:57:46, 10.89s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7369:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7344/9975 [32:01<6:20:52,  8.69s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7362:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7360:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7346/9975 [32:01<4:02:54,  5.54s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7366:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7372:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7364:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7349/9975 [32:02<2:16:22,  3.12s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7370:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7371:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7351/9975 [32:02<1:38:15,  2.25s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7373:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7363:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7353/9975 [32:03<1:15:14,  1.72s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7368:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7354/9975 [32:05<1:14:54,  1.71s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7358:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7355/9975 [32:17<2:52:34,  3.95s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7350:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7347:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▎  | 7356/9975 [32:18<2:16:52,  3.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7351:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7357:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7353:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7344:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7352:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7345:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7341:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7375:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7365/9975 [33:02<3:12:25,  4.42s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7382:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7366/9975 [33:02<2:56:12,  4.05s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7384:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7367/9975 [33:03<2:38:44,  3.65s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7385:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7368/9975 [33:05<2:25:28,  3.35s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7390:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7369/9975 [33:18<3:41:50,  5.11s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7386:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7389:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7371/9975 [33:19<2:29:10,  3.44s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7387:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7372/9975 [33:19<2:03:54,  2.86s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7393:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7373/9975 [33:19<1:40:01,  2.31s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7388:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7391:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7392:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7376/9975 [33:20<53:19,  1.23s/it]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7395:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7377/9975 [33:20<49:26,  1.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7394:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7378/9975 [33:21<44:57,  1.04s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7381:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7379/9975 [33:32<2:26:00,  3.37s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7383:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7380/9975 [33:33<1:52:28,  2.60s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7380:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7379:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7374:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7383/9975 [33:34<1:04:26,  1.49s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7378:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7384/9975 [33:34<52:33,  1.22s/it]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7376:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7385/9975 [33:34<42:34,  1.01it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7377:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7386/9975 [33:37<1:01:16,  1.42s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7397:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7387/9975 [34:03<5:33:32,  7.73s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7396:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7388/9975 [34:04<4:08:19,  5.76s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7398:
#   warnings.warn(f"error for {i}: {e}")
#  74%|███████▍  | 7389/9975 [34:04<3:08:18,  4.37s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7399:
#   warnings.warn(f"error for {i}: {e}")
#  77%|███████▋  | 7663/9975 [34:54<03:39, 10.52it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7405:
#   warnings.warn(f"error for {i}: {e}")
#  77%|███████▋  | 7667/9975 [34:54<02:44, 14.02it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7407:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7408:
#   warnings.warn(f"error for {i}: {e}")
#  77%|███████▋  | 7671/9975 [34:54<02:43, 14.06it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7404:
#   warnings.warn(f"error for {i}: {e}")
#  77%|███████▋  | 7697/9975 [34:56<02:51, 13.27it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7406:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8284/9975 [35:46<22:43,  1.24it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7590:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8287/9975 [35:49<28:24,  1.01s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 7430: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2014-hanse-345-8626905/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8310/9975 [37:14<40:09,  1.45s/it]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8319:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8311/9975 [37:15<29:13,  1.05s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8328:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8321:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8313/9975 [37:15<16:21,  1.69it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8323:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8314/9975 [37:15<14:36,  1.90it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8325:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8322:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8316/9975 [37:15<09:22,  2.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8326:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 8318/9975 [37:15<07:17,  3.79it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8320:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8324:
#   warnings.warn(f"error for {i}: {e}")
#  89%|████████▉ | 8876/9975 [38:21<07:32,  2.43it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_37996\1465481981.py:17: UserWarning: error for 8344: HTTPSConnectionPool(host='www.yachtworld.com', port=443): Max retries exceeded with url: /yacht/2003-vismara-farr-vismara-65'-fast-cruiser-7717203/ (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None)))
#   warnings.warn(f"error for {i}: {e}")
#  89%|████████▉ | 8892/9975 [38:26<05:43,  3.15it/s]

# %%
a = {1:2}
a.pop(1)
a.pop(3, None)
a
# Out:
# {}

# %%
error_list # , yacht_data_list
# error_list, yacht_data_list
# links[1890]
len(error_list)
# Out:
# 575

# %%
with ThreadPoolExecutor(max_workers=32) as t:
    tasks = [t.submit(set_data, k) for k in error_list.keys()]
    # tasks = [t.submit(set_data, i) for i in np.random.choice(len(links), 64, replace=False)]
    # tasks = [t.submit(set_data, i) for i in range(64)]
    for future in tqdm(as_completed(tasks), total=len(tasks)):
        pass
# Out:
#  75%|███████▍  | 431/575 [01:08<04:10,  1.74s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2912:
#   warnings.warn(f"error for {i}: {e}")
#  98%|█████████▊| 565/575 [03:56<00:58,  5.84s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 5933:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 569/575 [05:19<02:01, 20.23s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 8208:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 570/575 [06:35<03:05, 37.05s/it]

# %%
links[1860], 
# get_yacht_data(links[2106])
# Out:
# ('https://www.yachtworld.com/yacht/1999-bavaria-36-holiday-8171564/',)

# %%
data_list = list(filter(lambda x:not isinstance(x, int) and isinstance(x, dict), yacht_data_list))
len(data_list)
# Out:
# 2152

# %%
df = pd.DataFrame(data_list)
df.head()
# Out:
#   Basic.Year Basic.Make              Basic.Model Basic.Class Basic.Length  \
# 0       2023   Beneteau  Oceanis 46.1 - In Stock     Cruiser         46ft
# 1       2023   Jeanneau          Sun Odyssey 440     Cruiser         44ft
# 2       2023   Jeanneau          Sun Odyssey 490     Cruiser         49ft
# 3       2023   Jeanneau                       60     Cruiser         60ft
# 4       2023   Jeanneau                 Yacht 65     Cruiser         65ft
#
#   Basic.FuelType Basic.HullMaterial  \
# 0         Diesel         Fiberglass
# 1         Diesel         Fiberglass
# 2         Diesel         Fiberglass
# 3         Diesel         Fiberglass
# 4         Diesel         Fiberglass
#
#                                     Basic.OfferedBy        name  \
# 0  Cape Yachts at South Wharf - South Dartmouth, MA  Propulsion
# 1                    Marine Servicenter - San Diego  Propulsion
# 2                      Marine Servicenter - Seattle  Propulsion
# 3                    Marine Servicenter - San Diego  Propulsion
# 4                      Marine Servicenter - Seattle  Propulsion
#
#   Basic.EngineMake  ... Features.OutsideEquipment.WindGenerator  \
# 0           yanmar  ...                                     NaN
# 1           Yanmar  ...                                     NaN
# 2           Yanmar  ...                                     NaN
# 3           Yanmar  ...                                     NaN
# 4            Volvo  ...                                     NaN
#
#   Features.InsideEquipment.Seakeeper Features.InsideEquipment.AirCompressor  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#   Features.InsideEquipment.ChemicalHead  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Specifications.Miscellaneous.LiferaftCapacity  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Features.Rigging.HydraulicWinch Basic.RopeCutter  \
# 0                             NaN              NaN
# 1                             NaN              NaN
# 2                             NaN              NaN
# 3                             NaN              NaN
# 4                             NaN              NaN
#
#   Specifications.Miscellaneous.DeadriseAtTransom  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Features.AdditionalEquipment.LaunchingTrailer  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Features.AdditionalEquipment.BeachingLegs
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 124 columns]

# %%
with pd.ExcelWriter('../../data/爬取的数据.xlsx') as writer:
    df.to_excel(writer, sheet_name='二手帆船', index=False)

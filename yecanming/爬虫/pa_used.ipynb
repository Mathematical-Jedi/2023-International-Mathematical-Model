# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# 设置请求头部信息，模拟浏览器请求
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
# 设置YachtWorld网站上的搜索条件
search_params = {
    'class': 'sail',
    # 'price': 'USD100000-500000',
    # 'length': '40-50ft'
}
base_url = 'https://www.yachtworld.com'

requests.get(base_url, 
    headers=headers)
# Out:
# <Response [200]>

# %% [markdown]
# ## 探索性分析每一个具体url的页面结构

# %%
#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div.boat-details-content > div.details
link = 'https://www.yachtworld.com/yacht/2009-royal-huisman-j-class-yacht-6750313/'
res = requests.get(link, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')
soup.text
# Out:
# 'HANUMAN Racer Royal Huisman for sale - YachtWorld✕YachtWorld AppMake your dream come true todayOpenBoatsPower BoatsSailboatsSell Your BoatPersonal Boat ShopperResearchServicesYacht BrokersBoat DealersSurveyorsYacht LoansInsuranceBoat TransportDirectoryToggle NavigationUnited States (English) ▼ Danmark - Dansk Deutschland - Deutsch Australia - English United Kingdom - English España - Español Suomi - suomi France - Français Italia - Italiano Nederland - Nederlands Norge - Norsk Sverige - SvenskaLogin  CloseBurgess LondonCunard House, London, SW1Y 4LR, United KingdomView phone numberCloseMit Verkäufer in Kontakt treten* Please correct highlighted errors.NamePhone (optional)EmailMessageI recently viewed your listing on YachtWorld and I am interested in more details. Thank you.NameE-Mail sendenHome⁄/Boats for sale⁄/Sail⁄/Racer⁄/Royal Huisman⁄/2009 Royal Huisman J Class Yacht2009 Royal Huisman J Class YachtUS$14,900,000Newport, Rhode Island1/14Image coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soonImage coming soon1 of 14ContactMore from this BrokerShareView 14 PhotosBurgess LondonCunard House, London, SW1Y 4LR, United KingdomView phone numberCloseMit Verkäufer in Kontakt treten* Please correct highlighted errors.NamePhone (optional)EmailMessageI recently viewed your listing on YachtWorld and I am interested in more details. Thank you.NameE-Mail senden2009 Royal Huisman J Class Yacht HANUMAN138ftUS$14,900,000 tax not paidNewport, Rhode IslandBasicsYear2009MakeRoyal HuismanModelJ Class YachtClassRacerLength138.12ftFuel TypeDieselHull MaterialAluminumOffered ByBurgess LondonDescription2009 Royal Huisman J Class YachtBuilt in The Netherlands by Royal Huisman, HANUMAN is one of the most remarkable and highly revered J-Class sailing yachts. HANUMAN has benefited from a vast level of highly customised refits including a complete overhaul of all her racing and sailing systems in advance of the 2017 World Championships. She is "the" J-Class to own and offered for sale with a huge inventory. Her spectacular interior, created by Pieter Beeldsnijder, accommodates up to six guests in 3 en suite cabins, including a full beam owner\'s cabin.Show MoreContact InformationPlease contact Henry Craven-Smith at +44 (0)7796 278 797Other DetailsDisclaimerThe Company offers the details of this vessel in good faith but cannot guarantee or warrant the accuracy of this information nor warrant the condition of the vessel. A buyer should instruct his agents, or his surveyors, to investigate such details as the buyer desires validated. This vessel is offered subject to prior sale, price change, or withdrawal without notice.FeaturesElectrical EquipmentShore Power Inlet✓Generator✓ElectronicsDepthsounder✓Radar✓Log-Speedometer✓Radar Detector✓Wind Speed and Direction✓Computer✓Repeater(s)✓TV Set✓Navigation Center✓Plotter✓DVD Player✓Autopilot✓Radio✓Compas✓GPS✓Cockpit Speakers✓VHF✓Inside EquipmentDishwasher✓Bow Thruster✓Washing Machine✓Electric Bilge Pump✓Oven✓Manual Bilge Pump✓Marine Head✓Air Conditioning✓Electric Head✓Chemical Head✓Hot Water✓Refrigerator✓Fresh Water Maker✓Deep Freezer✓Sea Water Pump✓Battery Charger✓Outside EquipmentTeak Cockpit✓Teak Sidedecks✓Gangway✓Tender✓Liferaft✓Cockpit Cushions✓Swimming Ladder✓RiggingSteering Wheel✓Electric Winch✓Spinnaker Pole✓Hydraulic Winch✓PropulsionEngine MakeScaniaEngine Model350hp Scania DI 12 59M Total Power347.32hpFuel TypeDieselPropeller Type4 BladeSpecificationsDimensionsLength Overall138.12ftLength on Deck137.8ftMax Draft15.49ftBeam21.65ftLength at Waterline90.81ftTanksFresh Water Tank1 x 766.1 gal ()Fuel Tank1 x 2176.78 gal ()Holding Tank()AccommodationsDouble Berths2Twin Berths1Cabins3Heads6Request InformationCallMore yachts from Burgess London2005 Moonen Motor Yacht€4,950,000 (US$5,379,412)Corfu, GreeceBurgess London2009 Lurssen 60m DisplacementUS$59 ...

# %%
detail = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div.boat-details-content > div.details')
detail.text
# Out:
# 'BasicsYear2009MakeRoyal HuismanModelJ Class YachtClassRacerLength138.12ftFuel TypeDieselHull MaterialAluminumOffered ByBurgess LondonDescription2009 Royal Huisman J Class YachtBuilt in The Netherlands by Royal Huisman, HANUMAN is one of the most remarkable and highly revered J-Class sailing yachts. HANUMAN has benefited from a vast level of highly customised refits including a complete overhaul of all her racing and sailing systems in advance of the 2017 World Championships. She is "the" J-Class to own and offered for sale with a huge inventory. Her spectacular interior, created by Pieter Beeldsnijder, accommodates up to six guests in 3 en suite cabins, including a full beam owner\'s cabin.Show MoreContact InformationPlease contact Henry Craven-Smith at +44 (0)7796 278 797Other DetailsDisclaimerThe Company offers the details of this vessel in good faith but cannot guarantee or warrant the accuracy of this information nor warrant the condition of the vessel. A buyer should instruct his agents, or his surveyors, to investigate such details as the buyer desires validated. This vessel is offered subject to prior sale, price change, or withdrawal without notice.FeaturesElectrical EquipmentShore Power Inlet✓Generator✓ElectronicsDepthsounder✓Radar✓Log-Speedometer✓Radar Detector✓Wind Speed and Direction✓Computer✓Repeater(s)✓TV Set✓Navigation Center✓Plotter✓DVD Player✓Autopilot✓Radio✓Compas✓GPS✓Cockpit Speakers✓VHF✓Inside EquipmentDishwasher✓Bow Thruster✓Washing Machine✓Electric Bilge Pump✓Oven✓Manual Bilge Pump✓Marine Head✓Air Conditioning✓Electric Head✓Chemical Head✓Hot Water✓Refrigerator✓Fresh Water Maker✓Deep Freezer✓Sea Water Pump✓Battery Charger✓Outside EquipmentTeak Cockpit✓Teak Sidedecks✓Gangway✓Tender✓Liferaft✓Cockpit Cushions✓Swimming Ladder✓RiggingSteering Wheel✓Electric Winch✓Spinnaker Pole✓Hydraulic Winch✓PropulsionEngine MakeScaniaEngine Model350hp Scania DI 12 59M Total Power347.32hpFuel TypeDieselPropeller Type4 BladeSpecificationsDimensionsLength Overall138.12ftLength on Deck137.8ftMax Draft15.49ftBeam21.65ftLength at Waterline90.81ftTanksFresh Water Tank1 x 766.1 gal ()Fuel Tank1 x 2176.78 gal ()Holding Tank()AccommodationsDouble Berths2Twin Berths1Cabins3Heads6Request InformationCallMore yachts from Burgess London2005 Moonen Motor Yacht€4,950,000 (US$5,379,412)Corfu, GreeceBurgess London2009 Lurssen 60m DisplacementUS$59,990,000Abu Dhabi, United Arab EmiratesBurgess London2006 Custom Alstom Leroux€62,500,000 (US$67,921,863)West Palm Beach, FloridaBurgess London2013 Mondomarine 41M€9,900,000 (US$10,758,823)Sardinia, ItalyBurgess LondonMore from this Broker Visit WebsiteServices'

# %%
items = detail.select('div.header')
len(items)
items[0].text
items[0].next_sibling
for i in range(len(items)):
    if items[i].text.lower()=='specifications':
        break
i
# items[i].text
# Out:
# 6

# %%
def kv_attributes(basic, name='Basic'):
    titles = [f'{name}.{"".join(map(lambda x:x.capitalize(),t.text.strip().split()))}' for t in basic.select('td.datatable-title')]
    values = [t.text.strip() for t in basic.select('td.datatable-value')]
    return {k:v for k,v in zip(titles, values)}
kv_attributes(items[0].next_sibling)
# Out:
# {'Basic.Year': '2009',
#  'Basic.Make': 'Royal Huisman',
#  'Basic.Model': 'J Class Yacht',
#  'Basic.Class': 'Racer',
#  'Basic.Length': '138.12ft',
#  'Basic.FuelType': 'Diesel',
#  'Basic.HullMaterial': 'Aluminum',
#  'Basic.OfferedBy': 'Burgess London'}

# %%
def specification_attributes(specification, name='Specification'):
    sub_categories = specification.select('div.datatable-category')
    titles = []
    values = []
    for category in sub_categories:
        cate_name = category.find(attrs='sub-title').text
        cate_name = ''.join(map(lambda x:x.capitalize(), cate_name.split()))
        titles += [f'{name}.{cate_name}.{"".join(map(lambda x:x.capitalize(),t.text.strip().split()))}' for t in category.select('td.datatable-title')]
        values += [t.text.strip() for t in category.select('td.datatable-value')]
    return {k:v for k,v in zip(titles, values)}
specification_attributes(items[4].next_sibling, 'Features')
# Out:
# {'Features.ElectricalEquipment.ShorePowerInlet': '✓',
#  'Features.ElectricalEquipment.Generator': '✓',
#  'Features.Electronics.Depthsounder': '✓',
#  'Features.Electronics.Radar': '✓',
#  'Features.Electronics.Log-speedometer': '✓',
#  'Features.Electronics.RadarDetector': '✓',
#  'Features.Electronics.WindSpeedAndDirection': '✓',
#  'Features.Electronics.Computer': '✓',
#  'Features.Electronics.Repeater(s)': '✓',
#  'Features.Electronics.TvSet': '✓',
#  'Features.Electronics.NavigationCenter': '✓',
#  'Features.Electronics.Plotter': '✓',
#  'Features.Electronics.DvdPlayer': '✓',
#  'Features.Electronics.Autopilot': '✓',
#  'Features.Electronics.Radio': '✓',
#  'Features.Electronics.Compas': '✓',
#  'Features.Electronics.Gps': '✓',
#  'Features.Electronics.CockpitSpeakers': '✓',
#  'Features.Electronics.Vhf': '✓',
#  'Features.InsideEquipment.Dishwasher': '✓',
#  'Features.InsideEquipment.BowThruster': '✓',
#  'Features.InsideEquipment.WashingMachine': '✓',
#  'Features.InsideEquipment.ElectricBilgePump': '✓',
#  'Features.InsideEquipment.Oven': '✓',
#  'Features.InsideEquipment.ManualBilgePump': '✓',
#  'Features.InsideEquipment.MarineHead': '✓',
#  'Features.InsideEquipment.AirConditioning': '✓',
#  'Features.InsideEquipment.ElectricHead': '✓',
#  'Features.InsideEquipment.ChemicalHead': '✓',
#  'Features.InsideEquipment.HotWater': '✓',
#  'Features.InsideEquipment.Refrigerator': '✓',
#  'Features.InsideEquipment.FreshWaterMaker': '✓',
#  'Features.InsideEquipment.DeepFreezer': '✓',
#  'Features.InsideEquipment.SeaWaterPump': '✓',
#  'Features.InsideEquipment.BatteryCharger': '✓',
#  'Features.OutsideEquipment.TeakCockpit': '✓',
#  'Features.OutsideEquipment.TeakSidedecks': '✓',
#  'Features.OutsideEquipment.Gangway': '✓',
#  'Features.OutsideEquipment.Tender': '✓',
#  'Features.OutsideEquipment.Liferaft': '✓',
#  'Features.OutsideEquipment.CockpitCushions': '✓',
#  'Features.OutsideEquipment.SwimmingLadder': '✓',
#  'Features.Rigging.SteeringWheel': '✓',
#  'Features.Rigging.ElectricWinch': '✓',
#  'Features.Rigging.SpinnakerPole': '✓',
#  'Features.Rigging.HydraulicWinch': '✓'}

# %%
def get_price(soup):

    price = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div > div.summary > div > span.payment-total')

    # price.text.strip().split('$')[1]
    x = float("".join(list(filter(str.isdigit,price.text.split('US$')[1]))))
    return x
get_price(soup)
# Out:
# 14900000.0

# %%
sn = requests.Session()

# %%
# 爬取所有帆船的year属性和价格数据，并将它们存储到CSV文件中
import warnings


def get_yacht_data(url):
    # res = requests.get(url, headers=headers)
    res = sn.get(url, headers=headers)
    return get_yacht_data_req_res(res)
    
def get_yacht_data_req_res(req_res):
    soup = BeautifulSoup(req_res.text, 'html.parser')
    detail = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div.boat-details-content > div.details')
    assert detail is not None
    items = detail.select('div.header')
    assert len(items)>0
    result = {}
    for i, item in enumerate(items):
            if item.text.lower()=='BASICS'.lower() or item.text.lower()=='PROPULSION'.lower():
                result.update(kv_attributes(items[i].next_sibling), name=item.text.lower().capitalize())
            elif item.text.lower()=='SPECIFICATIONS'.lower() or item.text.lower()=='FEATURES'.lower():
                result.update(specification_attributes(items[i].next_sibling, name=item.text.lower().capitalize()))
    try:
        result['Price'] = get_price(soup)
    except Exception as e:
        # warnings.warn(f"no price for {url}")
        pass
    return result
    
get_yacht_data(link)
# Out:
# {'Basic.Year': '2009',
#  'Basic.Make': 'Royal Huisman',
#  'Basic.Model': 'J Class Yacht',
#  'Basic.Class': 'Racer',
#  'Basic.Length': '138.12ft',
#  'Basic.FuelType': 'Diesel',
#  'Basic.HullMaterial': 'Aluminum',
#  'Basic.OfferedBy': 'Burgess London',
#  'name': 'Propulsion',
#  'Features.ElectricalEquipment.ShorePowerInlet': '✓',
#  'Features.ElectricalEquipment.Generator': '✓',
#  'Features.Electronics.Depthsounder': '✓',
#  'Features.Electronics.Radar': '✓',
#  'Features.Electronics.Log-speedometer': '✓',
#  'Features.Electronics.RadarDetector': '✓',
#  'Features.Electronics.WindSpeedAndDirection': '✓',
#  'Features.Electronics.Computer': '✓',
#  'Features.Electronics.Repeater(s)': '✓',
#  'Features.Electronics.TvSet': '✓',
#  'Features.Electronics.NavigationCenter': '✓',
#  'Features.Electronics.Plotter': '✓',
#  'Features.Electronics.DvdPlayer': '✓',
#  'Features.Electronics.Autopilot': '✓',
#  'Features.Electronics.Radio': '✓',
#  'Features.Electronics.Compas': '✓',
#  'Features.Electronics.Gps': '✓',
#  'Features.Electronics.CockpitSpeakers': '✓',
#  'Features.Electronics.Vhf': '✓',
#  'Features.InsideEquipment.Dishwasher': '✓',
#  'Features.InsideEquipment.BowThruster': '✓',
#  'Features.InsideEquipment.WashingMachine': '✓',
#  'Features.InsideEquipment.ElectricBilgePump': '✓',
#  'Features.InsideEquipment.Oven': '✓',
#  'Features.InsideEquipment.ManualBilgePump': '✓',
#  'Features.InsideEquipment.MarineHead': '✓',
#  'Features.InsideEquipment.AirConditioning': '✓',
#  'Features.InsideEquipment.ElectricHead': '✓',
#  'Features.InsideEquipment.ChemicalHead': '✓',
#  'Features.InsideEquipment.HotWater': '✓',
#  'Features.InsideEquipment.Refrigerator': '✓',
#  'Features.InsideEquipment.FreshWaterMaker': '✓',
#  'Features.InsideEquipment.DeepFreezer': '✓',
#  'Features.InsideEquipment.SeaWaterPump': '✓',
#  'Features.InsideEquipment.BatteryCharger': '✓',
#  'Features.OutsideEquipment.TeakCockpit': '✓',
#  'Features.OutsideEquipment.TeakSidedecks': '✓',
#  'Features.OutsideEquipment.Gangway': '✓',
#  'Features.OutsideEquipment.Tender': '✓',
#  'Features.OutsideEquipment.Liferaft': '✓',
#  'Features.OutsideEquipment.CockpitCushions': '✓',
#  'Features.OutsideEquipment.SwimmingLadder': '✓',
#  'Features.Rigging.SteeringWheel': '✓',
#  'Features.Rigging.ElectricWinch': '✓',
#  'Features.Rigging.SpinnakerPole': '✓',
#  'Features.Rigging.HydraulicWinch': '✓',
#  'Basic.EngineMake': 'Scania',
#  'Basic.EngineModel': '350hp Scania DI 12 59M',
#  'Basic.TotalPower': '347.32hp',
#  'Basic.PropellerType': '4 Blade',
#  'Specifications.Dimensions.LengthOverall': '138.12ft',
#  'Specifications.Dimensions.LengthOnDeck': '137.8ft',
#  'Specifications.Dimensions.MaxDraft': '15.49ft',
#  'Specifications.Dimensions.Beam': '21.65ft',
#  'Specifications.Dimensions.LengthAtWaterline': '90.81ft',
#  'Specifications.Tanks.FreshWaterTank': '1 x 766.1 gal ()',
#  'Specifications.Tanks.FuelTank': '1 x 2176.78 gal ()',
#  'Specifications.Tanks.HoldingTank': '()',
#  'Specifications.Accommodations.DoubleBerths': '2',
#  'Specifications.Accommodations.TwinBerths': '1',
#  'Specifications.Accommodations.Cabins': '3',
#  'Specifications.Accommodations.Heads': '6',
#  'Price': 14900000.0}

# %%
with open('old_links.txt', 'r') as f:
    links = f.read().split()
links[:5]
# Out:
# ['https://www.yachtworld.com/yacht/2021-sunreef-60-sail-8672222/',
#  'https://www.yachtworld.com/yacht/1979-orion-sparkman-$-stephens-sloop-8474326/',
#  'https://www.yachtworld.com/yacht/1981-baltic-42-dp-8381625/',
#  'https://www.yachtworld.com/yacht/2023-jeanneau-sun-odyssey-349-7835504/',
#  'https://www.yachtworld.com/yacht/2014-schock-harbor-25-8432704/']

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import numpy as np
from tqdm import tqdm
yacht_data_list = list(range(len(links)))
error_list = {}
def set_data(i):
    # print(i)
    try:
        yacht_data_list[i] = get_yacht_data(links[i])
    except Exception as e:
        time.sleep(60)
        try:
            yacht_data_list[i] = get_yacht_data(links[i])
        except:
            error_list[i]=e
            warnings.warn(f"error for {i}: {e}")
        else:
            error_list.pop(i, None)
    else:
        error_list.pop(i, None)

# %%
# with ThreadPoolExecutor(max_workers=64) as t:
with ThreadPoolExecutor(max_workers=32) as t:
    tasks = [t.submit(set_data, i) for i in range(len(links))]
    # tasks = [t.submit(set_data, i) for i in np.random.choice(len(links), 64, replace=False)]
    # tasks = [t.submit(set_data, i) for i in range(64)]
    for future in tqdm(as_completed(tasks), total=len(tasks)):
        pass
# Out:
#  25%|██▌       | 2504/9975 [02:22<08:34, 14.53it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2462:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2505/9975 [03:00<11:24:06,  5.49s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2488:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2506/9975 [03:01<10:26:14,  5.03s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2493:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2496:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2508/9975 [03:02<7:54:22,  3.81s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2501:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2500:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2510/9975 [03:02<5:51:46,  2.83s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2504:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2506:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2505:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2510:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2507:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2503:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2512:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2514:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2518/9975 [03:02<2:20:38,  1.13s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2515:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2521:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2520/9975 [03:02<1:57:16,  1.06it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2523:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2519:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2522/9975 [03:03<1:36:40,  1.28it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2518:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2516:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2525:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2520:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2526/9975 [03:03<1:02:33,  1.98it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2517:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2528:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2527:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2526:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2530:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2531/9975 [03:03<39:29,  3.14it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2531:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2532:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2533:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2534/9975 [03:03<32:12,  3.85it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2534:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2535:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2536/9975 [03:22<28:30,  4.35it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2536:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2537/9975 [04:00<14:38:18,  7.09s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2537:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2538/9975 [04:02<12:58:28,  6.28s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2538:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2539:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2540/9975 [04:02<9:16:57,  4.49s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2540:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2541/9975 [04:02<7:41:51,  3.73s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2541:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 2542/9975 [04:02<6:13:13,  3.01s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2542:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2545:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2544:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2543:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2547:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2546:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2548:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2549/9975 [04:03<2:05:23,  1.01s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2549:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2550:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2552:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2552/9975 [04:03<1:33:51,  1.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2553:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2554:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2555:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2555/9975 [04:03<1:08:24,  1.81it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2556:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2558:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2557:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2561:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2559:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2560:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2560/9975 [04:03<41:23,  2.99it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2551:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2563:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2563/9975 [04:03<32:17,  3.83it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2565:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2562:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2564:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2566/9975 [04:04<27:42,  4.46it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2566:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2567:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2566/9975 [04:22<27:42,  4.46it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2568:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2569/9975 [05:00<11:09:35,  5.42s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2569:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2570/9975 [05:02<10:14:50,  4.98s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2570:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2571:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2572/9975 [05:03<7:48:46,  3.80s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2572:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2575:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2574/9975 [05:03<5:50:29,  2.84s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2574:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2573:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2577:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2576:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2580:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2579:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2580/9975 [05:03<2:45:28,  1.34s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2578:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2582:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2581:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2583/9975 [05:03<2:01:52,  1.01it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2583:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2584:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2585:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2586/9975 [05:03<1:31:28,  1.35it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2586:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2587:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2588:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2589:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2590:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2592:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2592/9975 [05:04<51:34,  2.39it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2591:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2593:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2594:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2595/9975 [05:04<40:48,  3.01it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2595:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2596:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2597:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2598/9975 [05:04<34:11,  3.60it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2598:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2599:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2598/9975 [05:22<34:11,  3.60it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2600:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2601/9975 [06:01<10:46:26,  5.26s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2601:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2602/9975 [06:02<9:55:58,  4.85s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2602:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2603:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2604/9975 [06:03<7:38:28,  3.73s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2604:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2605:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2606/9975 [06:03<5:45:12,  2.81s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2606:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2607:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2608:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2609:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2610:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2611/9975 [06:03<3:00:29,  1.47s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2612:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2611:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2613:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2614/9975 [06:03<2:09:36,  1.06s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2614:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2615:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2616:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▌       | 2617/9975 [06:04<1:35:33,  1.28it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2617:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2618:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2619:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2621:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▋       | 2621/9975 [06:04<1:02:20,  1.97it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2620:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2622:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2624:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2625:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▋       | 2625/9975 [06:04<42:53,  2.86it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2626:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2623:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2627:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▋       | 2628/9975 [06:04<34:23,  3.56it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2628:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2629:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2630:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▋       | 2631/9975 [06:04<26:37,  4.60it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2631:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▋       | 2631/9975 [06:22<26:37,  4.60it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2632:
#   warnings.warn(f"error for {i}: {e}")
#  26%|██▋       | 2633/9975 [07:01<12:20:18,  6.05s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2633:
#   warnings.warn(f"error for {i}: {e}")
#  42%|████▏     | 4173/9975 [08:21<03:48, 25.43it/s]   C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2912:
#   warnings.warn(f"error for {i}: {e}")
#  42%|████▏     | 4236/9975 [08:43<09:23, 10.18it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4181:
#   warnings.warn(f"error for {i}: {e}")
#  42%|████▏     | 4237/9975 [09:21<10:41:20,  6.71s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4195:
#   warnings.warn(f"error for {i}: {e}")
#  42%|████▏     | 4238/9975 [09:21<9:11:38,  5.77s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4193:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4201:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4240/9975 [09:21<6:33:22,  4.12s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4206:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4215:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4242/9975 [09:22<4:44:50,  2.98s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4217:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4221:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4244/9975 [09:22<3:24:06,  2.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4222:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4223:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4224:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4247/9975 [09:22<2:06:01,  1.32s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4225:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4231:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4249/9975 [09:22<1:34:48,  1.01it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4233:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4235:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4251/9975 [09:22<1:10:15,  1.36it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4236:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4242:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4243:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4253/9975 [09:23<55:26,  1.72it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4245:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4246:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4256/9975 [09:23<39:57,  2.39it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4253:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4257/9975 [09:23<36:14,  2.63it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4255:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4257:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4259/9975 [09:24<29:38,  3.21it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4258:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4260/9975 [09:25<42:55,  2.22it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4261:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4261/9975 [09:25<38:41,  2.46it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4260:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4262:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4263/9975 [09:25<26:18,  3.62it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4263:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4266:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4264:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4265:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4267/9975 [09:25<14:04,  6.76it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4267:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4267/9975 [09:43<14:04,  6.76it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4268:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4269/9975 [10:21<12:00:20,  7.57s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4269:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4270/9975 [10:21<10:08:02,  6.39s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4270:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4271:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4272/9975 [10:21<7:00:42,  4.43s/it] C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4272:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4273:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4274/9975 [10:22<4:57:51,  3.13s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4274:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4275/9975 [10:22<4:07:25,  2.60s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4275:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4276:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4277:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4278:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4279/9975 [10:22<2:03:28,  1.30s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4279:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4280:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4281/9975 [10:23<1:33:31,  1.01it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4281:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4282:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4283/9975 [10:23<1:09:13,  1.37it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4283:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4284:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4286:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4285/9975 [10:23<56:10,  1.69it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4285:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4287:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4288/9975 [10:24<39:09,  2.42it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4288:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4289/9975 [10:24<36:11,  2.62it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4289:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4290:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4291/9975 [10:24<28:57,  3.27it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4291:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4292/9975 [10:25<42:20,  2.24it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4292:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4293/9975 [10:25<38:37,  2.45it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4293:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4294:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4295:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4296/9975 [10:25<22:24,  4.22it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4296:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4297:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4298:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4299:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4296/9975 [10:43<22:24,  4.22it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4300:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4301/9975 [11:21<9:25:29,  5.98s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4301:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4302/9975 [11:22<8:14:16,  5.23s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4302:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4303:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4304/9975 [11:22<6:03:28,  3.85s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4304:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4305:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4306/9975 [11:22<4:28:29,  2.84s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4306:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4307/9975 [11:23<3:47:14,  2.41s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4307:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4308:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4309:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4310/9975 [11:23<2:14:33,  1.43s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4310:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4311:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4312:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4313/9975 [11:23<1:28:07,  1.07it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4313:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4314:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4315:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4316/9975 [11:23<59:43,  1.58it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4317:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4316:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4318/9975 [11:24<48:37,  1.94it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4318:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4319:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4320/9975 [11:24<40:05,  2.35it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4321:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4321/9975 [11:24<36:50,  2.56it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4320:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4322:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4323/9975 [11:24<29:22,  3.21it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4323:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4324/9975 [11:25<42:51,  2.20it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4324:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4325/9975 [11:26<39:12,  2.40it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4325:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4326:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4327:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4328/9975 [11:26<22:23,  4.20it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4328:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4329:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4330:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4331:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4328/9975 [11:44<22:23,  4.20it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4332:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4333/9975 [12:22<9:24:24,  6.00s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4333:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4334/9975 [12:22<8:13:09,  5.25s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4334:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4335:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4336/9975 [12:22<6:02:10,  3.85s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4336:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4337:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4338/9975 [12:23<4:27:19,  2.85s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4338:
#   warnings.warn(f"error for {i}: {e}")
#  43%|████▎     | 4339/9975 [12:23<3:46:09,  2.41s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4339:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4340:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4341:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4342/9975 [12:23<2:13:51,  1.43s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4343:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4342:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4344/9975 [12:23<1:37:12,  1.04s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4344:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4346:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4346/9975 [12:23<1:12:41,  1.29it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4345:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4347:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4348/9975 [12:24<53:44,  1.75it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4348:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4349:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4350/9975 [12:24<42:30,  2.21it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4350:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4351:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4352/9975 [12:24<34:43,  2.70it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4352:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4353/9975 [12:24<31:48,  2.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4353:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4354:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4355/9975 [12:25<25:24,  3.69it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4355:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4356/9975 [12:26<40:24,  2.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4356:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4357/9975 [12:26<36:59,  2.53it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4357:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4358:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4359:
#   warnings.warn(f"error for {i}: {e}")
#  44%|████▎     | 4360/9975 [12:26<20:52,  4.48it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4360:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4361:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4362:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 4363:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6048/9975 [15:49<7:13:42,  6.63s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6031:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6049/9975 [15:50<5:48:47,  5.33s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6040:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6039:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6050/9975 [15:50<4:30:42,  4.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6041:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6045:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6053/9975 [15:50<2:17:02,  2.10s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6047:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6054/9975 [15:50<1:52:15,  1.72s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6049:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6050:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6056/9975 [15:51<1:14:44,  1.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6051:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6052:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6058/9975 [15:51<50:52,  1.28it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6054:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6055:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6060/9975 [15:51<36:22,  1.79it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6058:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6061:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6062/9975 [15:52<38:18,  1.70it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6062:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6063/9975 [15:52<32:49,  1.99it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6063:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6069:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6065/9975 [15:53<23:38,  2.76it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6066:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6067:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6068:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6065:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6070:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6071:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6071/9975 [15:53<13:43,  4.74it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6072:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6072/9975 [16:16<3:16:59,  3.03s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6073:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6073/9975 [16:17<2:53:17,  2.66s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6074:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6074/9975 [16:19<2:53:27,  2.67s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6075:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6075/9975 [16:20<2:21:09,  2.17s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6076:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6076/9975 [16:20<1:56:31,  1.79s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6077:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6077/9975 [16:20<1:33:10,  1.43s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6078:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 6078/9975 [16:21<1:14:19,  1.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 6079:
#   warnings.warn(f"error for {i}: {e}")
# ...
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7899:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7900:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7901/9975 [24:55<43:29,  1.26s/it]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7901:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7902:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7903/9975 [24:55<32:50,  1.05it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7903:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7904:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7905/9975 [24:55<24:38,  1.40it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7905:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7906:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7907:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7908/9975 [24:55<16:06,  2.14it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7908:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7909:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7910:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7911:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7911/9975 [24:55<11:13,  3.06it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7912:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7913:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7913/9975 [24:55<08:58,  3.83it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7914:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7915/9975 [24:56<07:32,  4.55it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7915:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7916:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7917:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7918:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7918/9975 [24:56<05:50,  5.86it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7919:
#   warnings.warn(f"error for {i}: {e}")
#  79%|███████▉  | 7920/9975 [24:56<05:09,  6.63it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 7920:
#   warnings.warn(f"error for {i}: {e}")
#  94%|█████████▍| 9426/9975 [29:49<28:09,  3.08s/it]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9422:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9425:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9428/9975 [30:01<36:22,  3.99s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9428:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9429/9975 [30:02<30:54,  3.40s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9429:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9430:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9431:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9432/9975 [30:02<17:59,  1.99s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9433:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9433/9975 [30:03<16:40,  1.85s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 8208:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9434/9975 [30:11<27:22,  3.04s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9434:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9435/9975 [30:12<22:44,  2.53s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9435:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9436/9975 [30:15<23:02,  2.56s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9436:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9437/9975 [30:15<17:28,  1.95s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9437:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9438/9975 [30:15<13:40,  1.53s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9438:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9439/9975 [30:15<10:09,  1.14s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9439:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9440/9975 [30:15<07:43,  1.15it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9440:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9441/9975 [30:17<09:22,  1.05s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9441:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9442/9975 [30:18<08:47,  1.01it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9442:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9443/9975 [30:20<13:12,  1.49s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9443:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9444:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9445/9975 [30:22<10:17,  1.17s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9445:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9446:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9447/9975 [30:22<06:43,  1.31it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9448:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9448/9975 [30:23<06:59,  1.26it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9447:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9451:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9449:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9451/9975 [30:23<03:44,  2.34it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9452:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9454:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9450:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9453:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9455:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9451/9975 [30:39<03:44,  2.34it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9456:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9457/9975 [30:44<19:07,  2.22s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9457:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9458/9975 [30:49<21:56,  2.55s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9458:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9459/9975 [31:01<33:59,  3.95s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9459:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9460/9975 [31:02<28:19,  3.30s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9460:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9461/9975 [31:02<23:41,  2.77s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9461:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9462:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9463:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9464/9975 [31:03<13:11,  1.55s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9464:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9465/9975 [31:04<12:32,  1.48s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9465:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9466/9975 [31:12<23:43,  2.80s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9466:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9467/9975 [31:12<19:41,  2.33s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9467:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9468/9975 [31:15<20:22,  2.41s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9468:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9469/9975 [31:15<15:19,  1.82s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9469:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9470/9975 [31:16<12:03,  1.43s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9470:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9471:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9472/9975 [31:16<07:17,  1.15it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9472:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9473/9975 [31:17<08:33,  1.02s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9473:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9474/9975 [31:18<08:08,  1.02it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9475:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9474:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▍| 9475/9975 [31:21<11:54,  1.43s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9476:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9477/9975 [31:22<09:33,  1.15s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9477:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9478:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9479/9975 [31:23<06:21,  1.30it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9479:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9480/9975 [31:24<06:33,  1.26it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9480:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9481:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9482:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9483/9975 [31:24<03:32,  2.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9484:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9483:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9487:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9486:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9485:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9483/9975 [31:39<03:32,  2.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9488:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9489/9975 [31:45<17:53,  2.21s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9489:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9490/9975 [31:50<20:31,  2.54s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9491:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9492/9975 [32:02<26:51,  3.34s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9493:
#   warnings.warn(f"error for {i}: {e}")
#  95%|█████████▌| 9494/9975 [32:03<17:27,  2.18s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9495:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 9950/9975 [32:41<00:02, 10.04it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9520:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9521:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 9952/9975 [32:50<00:29,  1.30s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 9526:
#   warnings.warn(f"error for {i}: {e}")
# 100%|██████████| 9975/9975 [33:41<00:00,  4.93it/s]

# %%
a = {1:2}
a.pop(1)
a.pop(3, None)
a
# Out:
# {}

# %%
error_list # , yacht_data_list
# error_list, yacht_data_list
# links[1890]
len(error_list)
# Out:
# 575

# %%
with ThreadPoolExecutor(max_workers=32) as t:
    tasks = [t.submit(set_data, k) for k in error_list.keys()]
    # tasks = [t.submit(set_data, i) for i in np.random.choice(len(links), 64, replace=False)]
    # tasks = [t.submit(set_data, i) for i in range(64)]
    for future in tqdm(as_completed(tasks), total=len(tasks)):
        pass
# Out:
#  75%|███████▍  | 431/575 [01:08<04:10,  1.74s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 2912:
#   warnings.warn(f"error for {i}: {e}")
#  98%|█████████▊| 565/575 [03:56<00:58,  5.84s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 5933:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 569/575 [05:19<02:01, 20.23s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_23636\1465481981.py:17: UserWarning: error for 8208:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 570/575 [06:35<03:05, 37.05s/it]

# %%
links[1860], 
# get_yacht_data(links[2106])
# Out:
# ('https://www.yachtworld.com/yacht/1999-bavaria-36-holiday-8171564/',)

# %%
data_list = list(filter(lambda x:not isinstance(x, int) and isinstance(x, dict), yacht_data_list))
len(data_list)
# Out:
# 2152

# %%
df = pd.DataFrame(data_list)
df.head()
# Out:
#   Basic.Year Basic.Make              Basic.Model Basic.Class Basic.Length  \
# 0       2023   Beneteau  Oceanis 46.1 - In Stock     Cruiser         46ft
# 1       2023   Jeanneau          Sun Odyssey 440     Cruiser         44ft
# 2       2023   Jeanneau          Sun Odyssey 490     Cruiser         49ft
# 3       2023   Jeanneau                       60     Cruiser         60ft
# 4       2023   Jeanneau                 Yacht 65     Cruiser         65ft
#
#   Basic.FuelType Basic.HullMaterial  \
# 0         Diesel         Fiberglass
# 1         Diesel         Fiberglass
# 2         Diesel         Fiberglass
# 3         Diesel         Fiberglass
# 4         Diesel         Fiberglass
#
#                                     Basic.OfferedBy        name  \
# 0  Cape Yachts at South Wharf - South Dartmouth, MA  Propulsion
# 1                    Marine Servicenter - San Diego  Propulsion
# 2                      Marine Servicenter - Seattle  Propulsion
# 3                    Marine Servicenter - San Diego  Propulsion
# 4                      Marine Servicenter - Seattle  Propulsion
#
#   Basic.EngineMake  ... Features.OutsideEquipment.WindGenerator  \
# 0           yanmar  ...                                     NaN
# 1           Yanmar  ...                                     NaN
# 2           Yanmar  ...                                     NaN
# 3           Yanmar  ...                                     NaN
# 4            Volvo  ...                                     NaN
#
#   Features.InsideEquipment.Seakeeper Features.InsideEquipment.AirCompressor  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#   Features.InsideEquipment.ChemicalHead  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Specifications.Miscellaneous.LiferaftCapacity  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Features.Rigging.HydraulicWinch Basic.RopeCutter  \
# 0                             NaN              NaN
# 1                             NaN              NaN
# 2                             NaN              NaN
# 3                             NaN              NaN
# 4                             NaN              NaN
#
#   Specifications.Miscellaneous.DeadriseAtTransom  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Features.AdditionalEquipment.LaunchingTrailer  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Features.AdditionalEquipment.BeachingLegs
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 124 columns]

# %%
with pd.ExcelWriter('../../data/爬取的数据.xlsx') as writer:
    df.to_excel(writer, sheet_name='二手帆船', index=False)

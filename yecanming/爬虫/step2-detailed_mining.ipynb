# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

import stable_get_html
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
# 设置请求头部信息，模拟浏览器请求
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
# base_url = 'https://www.yachtworld.com'
# requests.get(base_url, 
#     headers=headers)

# %%
def kv_attributes(basic, name='Basic'):
    titles = [f'{name}.{"".join(map(lambda x:x.capitalize(),t.text.strip().split()))}' for t in basic.select('td.datatable-title')]
    values = [t.text.strip() for t in basic.select('td.datatable-value')]
    return {k:v for k,v in zip(titles, values)}
def specification_attributes(specification, name='Specification'):
    sub_categories = specification.select('div.datatable-category')
    titles = []
    values = []
    for category in sub_categories:
        cate_name = category.find(attrs='sub-title').text
        cate_name = ''.join(map(lambda x:x.capitalize(), cate_name.split()))
        titles += [f'{name}.{cate_name}.{"".join(map(lambda x:x.capitalize(),t.text.strip().split()))}' for t in category.select('td.datatable-title')]
        values += [t.text.strip() for t in category.select('td.datatable-value')]
    return {k:v for k,v in zip(titles, values)}
def get_price(soup):

    price = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div > div.summary > div > span.payment-total')

    # price.text.strip().split('$')[1]
    x = float("".join(list(filter(str.isdigit,price.text.split('US$')[1]))))
    return x

# %%
# sn = requests.Session()

# %%
import warnings
def get_yacht_data(url):
    """输入url返回一个字典

    Args:
        url (str): _description_

    Returns:
        dict: _description_
    """
    # res = requests.get(url, headers=headers)
    # res = sn.get(url, headers=headers)
    res = stable_get_html.get_html(url)
    return get_yacht_data_req_res(res)
def get_yacht_data_req_res(req_res):
    soup = BeautifulSoup(req_res.text, 'html.parser')
    detail = soup.select_one('#BoatDetails > div.content.nav-slide.with-sticky-contact.home-block > div.boat-details > div.body > div.boat-details-content > div.details')
    assert detail is not None
    items = detail.select('div.header')
    assert len(items)>0
    result = {}
    for i, item in enumerate(items):
            if item.text.lower()=='BASICS'.lower() or item.text.lower()=='PROPULSION'.lower():
                result.update(kv_attributes(items[i].next_sibling, name=item.text.lower().capitalize()))
            elif item.text.lower()=='SPECIFICATIONS'.lower() or item.text.lower()=='FEATURES'.lower():
                result.update(specification_attributes(items[i].next_sibling, name=item.text.lower().capitalize()))
    try:
        result['Price'] = get_price(soup)
    except Exception as e:
        # warnings.warn(f"no price for {url}")
        pass
    return result

# %%
links_table = pd.read_csv('all_links.csv', index_col=0)
links_table.head(6)
# Out:
#                                                 Link     Price  \
# 0  https://www.yachtworld.com/yacht/2023-jeanneau...  329795.0
# 1  https://www.yachtworld.com/yacht/2023-dufour-3...  364999.0
# 2  https://www.yachtworld.com/yacht/2023-bavaria-...  432319.0
# 3  https://www.yachtworld.com/yacht/1984-union-po...   31000.0
# 4  https://www.yachtworld.com/yacht/2023-dufour-4...  850000.0
# 5  https://www.yachtworld.com/yacht/2023-jeanneau...  519685.0
#
#                          Basics.Location   New
# 0     Seattle, Washington, United States  True
# 1       Racine, Wisconsin, United States  True
# 2   San Diego, California, United States  True
# 3  Emeryville, California, United States  True
# 4       Racine, Wisconsin, United States  True
# 5   San Diego, California, United States  True

# %%
# links_table.loc[4:6, 'Link']
links = links_table['Link'].to_list()
links[:5]
# Out:
# ['https://www.yachtworld.com/yacht/2023-jeanneau-380-8171644/',
#  'https://www.yachtworld.com/yacht/2023-dufour-37-8587334/',
#  'https://www.yachtworld.com/yacht/2023-bavaria-c42-8710488/',
#  'https://www.yachtworld.com/yacht/1984-union-polaris-8602417/',
#  'https://www.yachtworld.com/yacht/2023-dufour-470-8577883/']

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import numpy as np
from tqdm import tqdm
yacht_data_list = list(range(len(links)))
error_list = {}
def set_data(i):
    # print(i)
    try:
        yacht_data_list[i] = get_yacht_data(links[i])
    except Exception as e:
        # time.sleep(60)
        time.sleep(0.3)
        try:
            yacht_data_list[i] = get_yacht_data(links[i])
        except:
            error_list[i]=e
            warnings.warn(f"error for {i}: {e}")
            raise
            # return False
        else:
            error_list.pop(i, None)
            # return True
    else:
        error_list.pop(i, None)
        # return True

# %%
with ThreadPoolExecutor(max_workers=32) as t:
    tasks = [t.submit(set_data, i) for i in range(len(links))]
    # tasks = [t.submit(set_data, i) for i in np.random.choice(len(links), 64, replace=False)]
    # tasks = [t.submit(set_data, i) for i in range(64)]
    for future in tqdm(as_completed(tasks), total=len(tasks)):
        pass
# Out:
#   1%|▏         | 162/12475 [00:27<18:14, 11.25it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 8:
#   warnings.warn(f"error for {i}: {e}")
#   5%|▍         | 562/12475 [00:57<16:30, 12.03it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 432:
#   warnings.warn(f"error for {i}: {e}")
#   5%|▍         | 589/12475 [00:59<08:33, 23.14it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 468:
#   warnings.warn(f"error for {i}: {e}")
#   5%|▍         | 610/12475 [01:00<09:35, 20.61it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 491:
#   warnings.warn(f"error for {i}: {e}")
#  13%|█▎        | 1597/12475 [02:05<10:07, 17.91it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 1499:
#   warnings.warn(f"error for {i}: {e}")
#  16%|█▌        | 2000/12475 [02:27<09:43, 17.94it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 1945:
#   warnings.warn(f"error for {i}: {e}")
#  25%|██▌       | 3162/12475 [03:36<10:44, 14.44it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3101:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3717/12475 [04:59<3:57:31,  1.63s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3748:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3721/12475 [05:01<1:55:31,  1.26it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3749:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3722/12475 [05:01<1:32:25,  1.58it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3750:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3726/12475 [05:03<51:19,  2.84it/s]  C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3752:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3751:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3753:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3729/12475 [05:03<38:40,  3.77it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3754:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3730/12475 [05:03<33:53,  4.30it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3755:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3731/12475 [05:03<31:48,  4.58it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3756:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3732/12475 [05:04<37:59,  3.84it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3758:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3734/12475 [05:04<25:21,  5.74it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3757:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3759:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3760:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3737/12475 [05:05<28:37,  5.09it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3761:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3738/12475 [05:05<26:15,  5.55it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3762:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3763:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3740/12475 [05:05<30:27,  4.78it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3765:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3767:
#   warnings.warn(f"error for {i}: {e}")
#  30%|██▉       | 3742/12475 [05:05<24:03,  6.05it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3764:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3766:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3748/12475 [05:06<16:33,  8.78it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3768:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3769:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3770:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3750/12475 [05:06<18:18,  7.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3772:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3752/12475 [05:07<21:31,  6.75it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3771:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3774:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3754/12475 [05:07<17:54,  8.11it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3773:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3775:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3776:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3757/12475 [05:07<13:58, 10.39it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3778:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3777:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3759/12475 [05:07<15:43,  9.24it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3779:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3780:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3761/12475 [05:08<19:12,  7.56it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3782:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3781:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3763/12475 [05:08<16:32,  8.78it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3783:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3784:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3765/12475 [05:08<19:02,  7.63it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3786:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3785:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3787:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3768/12475 [05:08<14:29, 10.02it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3788:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3789:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3770/12475 [05:09<17:17,  8.39it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3790:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3791:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3772/12475 [05:09<16:05,  9.02it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3792:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3774/12475 [05:09<16:02,  9.04it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3793:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3794:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3776/12475 [05:09<14:18, 10.13it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3795:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3796:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3778/12475 [05:09<17:07,  8.46it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3798:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3779/12475 [05:10<17:26,  8.31it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3797:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3799:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3800:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3782/12475 [05:10<13:07, 11.04it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3802:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3801:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3784/12475 [05:10<16:18,  8.88it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3803:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3804:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3786/12475 [05:10<15:06,  9.59it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3805:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3788/12475 [05:10<14:02, 10.31it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3807:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3806:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3790/12475 [05:11<13:16, 10.90it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3808:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3809:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3792/12475 [05:11<14:56,  9.69it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3812:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3811:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3794/12475 [05:11<15:03,  9.61it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3810:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3813:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3814:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3797/12475 [05:11<15:39,  9.24it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3815:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3818:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3799/12475 [05:12<16:14,  8.90it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3816:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3817:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3819:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3802/12475 [05:12<14:30,  9.96it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3820:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3821:
#   warnings.warn(f"error for {i}: {e}")
#  30%|███       | 3804/12475 [05:12<12:50, 11.25it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3822:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3806/12475 [05:12<13:24, 10.77it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3823:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3825:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3808/12475 [05:12<14:22, 10.05it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3827:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3824:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3826:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3829:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3812/12475 [05:13<14:57,  9.65it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3828:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3830:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3814/12475 [05:13<14:39,  9.85it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3832:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3831:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3833:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3817/12475 [05:13<13:55, 10.36it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3835:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3834:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3838:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3820/12475 [05:14<13:33, 10.64it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3836:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3837:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3822/12475 [05:14<12:12, 11.81it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3839:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3841:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3824/12475 [05:14<11:59, 12.03it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3842:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3840:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3843:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3827/12475 [05:14<14:06, 10.21it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3844:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3845:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3829/12475 [05:14<13:44, 10.49it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3847:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3846:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3831/12475 [05:15<13:18, 10.82it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3848:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3849:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3833/12475 [05:15<13:26, 10.72it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3850:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3851:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3852:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3835/12475 [05:15<15:27,  9.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3853:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3854:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3838/12475 [05:15<12:34, 11.45it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3856:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3857:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3855:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3858:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3842/12475 [05:16<13:07, 10.97it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3859:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3860:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3844/12475 [05:16<14:27,  9.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3861:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3862:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3846/12475 [05:16<13:09, 10.93it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3863:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3865:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3848/12475 [05:16<13:55, 10.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3864:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3867:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3850/12475 [05:16<14:24,  9.97it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3866:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3868:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3852/12475 [05:17<12:26, 11.55it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3870:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3871:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3854/12475 [05:17<11:45, 12.22it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3872:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3869:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3873:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3857/12475 [05:17<12:25, 11.56it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3874:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3875:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3859/12475 [05:17<14:48,  9.70it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3876:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3878:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3861/12475 [05:17<14:32,  9.87it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3877:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3879:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3863/12475 [05:18<14:53,  9.64it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3880:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3881:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3865/12475 [05:18<13:29, 10.63it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3882:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3883:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3867/12475 [05:18<13:04, 10.97it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3886:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3885:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3869/12475 [05:18<11:27, 12.52it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3884:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3887:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3888:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3872/12475 [05:18<11:21, 12.62it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3889:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3890:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3874/12475 [05:19<15:57,  8.98it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3891:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3892:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3893:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3877/12475 [05:19<12:28, 11.48it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3895:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3894:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3879/12475 [05:19<14:14, 10.06it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3896:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3897:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3881/12475 [05:19<13:33, 10.56it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3898:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3899:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3883/12475 [05:19<13:43, 10.43it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3902:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3901:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3900:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3903:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3887/12475 [05:20<10:38, 13.45it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3904:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3905:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3889/12475 [05:20<16:07,  8.88it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3906:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3907:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3891/12475 [05:20<13:50, 10.34it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3908:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3909:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3893/12475 [05:20<14:56,  9.57it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3910:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3911:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3912:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3896/12475 [05:21<13:10, 10.85it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3913:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3915:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███       | 3898/12475 [05:21<12:33, 11.39it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3916:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3914:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3917:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3901/12475 [05:21<09:55, 14.41it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3918:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3919:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3903/12475 [05:21<14:38,  9.76it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3921:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3920:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3905/12475 [05:22<14:34,  9.80it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3922:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3923:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3907/12475 [05:22<13:46, 10.37it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3924:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3909/12475 [05:22<13:31, 10.55it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3926:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3925:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3911/12475 [05:22<14:02, 10.17it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3927:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3929:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3928:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3932:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3915/12475 [05:22<11:55, 11.97it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3931:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3930:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3933:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3918/12475 [05:23<11:28, 12.42it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3934:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3441:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3920/12475 [05:23<11:24, 12.49it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3936:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3935:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3922/12475 [05:23<12:20, 11.56it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3938:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3937:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3924/12475 [05:23<12:17, 11.60it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3940:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3939:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3926/12475 [05:23<11:53, 11.98it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3941:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3942:
#   warnings.warn(f"error for {i}: {e}")
#  31%|███▏      | 3928/12475 [05:23<12:06, 11.76it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3945:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3943:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3930/12475 [05:24<11:05, 12.84it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3944:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3946:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3932/12475 [05:24<11:07, 12.79it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3948:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3947:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3934/12475 [05:24<10:19, 13.80it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3949:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3950:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3936/12475 [05:24<13:14, 10.74it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3951:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3952:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3938/12475 [05:24<13:19, 10.68it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3953:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3955:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3940/12475 [05:24<13:07, 10.84it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3954:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3956:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3942/12475 [05:25<12:34, 11.31it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3463:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3958:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3957:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3959:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3947/12475 [05:25<08:05, 17.57it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3960:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3961:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3949/12475 [05:25<10:03, 14.13it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3962:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3963:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3964:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3952/12475 [05:25<09:24, 15.10it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3966:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3954/12475 [05:25<10:35, 13.42it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3965:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3967:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3956/12475 [05:26<11:02, 12.86it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3968:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3970:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3958/12475 [05:26<11:05, 12.80it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3969:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3971:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3960/12475 [05:26<11:21, 12.49it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3972:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3973:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3962/12475 [05:26<12:03, 11.77it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3974:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3975:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3978:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3964/12475 [05:26<11:55, 11.89it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3977:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3976:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3980:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3968/12475 [05:26<08:28, 16.74it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3979:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3981:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3982:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3971/12475 [05:27<08:10, 17.34it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3983:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3984:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3973/12475 [05:27<08:44, 16.20it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3985:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3986:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3975/12475 [05:27<09:31, 14.87it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3988:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3987:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3977/12475 [05:27<09:46, 14.50it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3989:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3991:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3979/12475 [05:27<12:11, 11.61it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3990:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3992:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3981/12475 [05:27<11:28, 12.34it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3994:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3993:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3983/12475 [05:28<11:13, 12.61it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3996:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3995:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3985/12475 [05:28<10:34, 13.38it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3997:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3998:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3999:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3988/12475 [05:28<08:57, 15.78it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4001:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4000:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4003:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3991/12475 [05:28<08:48, 16.04it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4002:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4004:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3993/12475 [05:28<08:36, 16.41it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4006:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4005:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3995/12475 [05:28<08:24, 16.80it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4008:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4007:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3997/12475 [05:28<09:57, 14.19it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4009:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4010:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 3999/12475 [05:29<12:40, 11.14it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3521:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4011:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4012:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4013:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 4004/12475 [05:29<09:32, 14.81it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4014:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4015:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4016:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 4007/12475 [05:29<08:08, 17.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4017:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4018:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 4009/12475 [05:29<08:28, 16.66it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4020:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4021:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 4011/12475 [05:29<09:23, 15.03it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4022:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4023:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4019:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4024:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 4015/12475 [05:30<08:35, 16.40it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4026:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4025:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4027:
#   warnings.warn(f"error for {i}: {e}")
#  32%|███▏      | 4018/12475 [05:30<10:04, 13.99it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4028:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4029:
# ...
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12372:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12367:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12375:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12376/12475 [12:00<00:03, 26.87it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12376:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12377:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12378:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12379/12475 [12:01<00:03, 25.16it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12379:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12380:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12382:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12382/12475 [12:01<00:04, 23.01it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12381:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12384:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12385:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12383:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12386/12475 [12:01<00:04, 22.20it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12389:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12387:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12388:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12386:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12389/12475 [12:01<00:04, 19.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12390:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12391:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12393:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12393/12475 [12:01<00:04, 19.82it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12392:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12394:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12395:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12396:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12397/12475 [12:01<00:03, 21.57it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12397:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12398:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12399:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12400/12475 [12:02<00:03, 22.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12401:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12400:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12404:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12403/12475 [12:02<00:03, 21.84it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12402:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12403:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12407:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12406:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12408:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12405:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12409:
#   warnings.warn(f"error for {i}: {e}")
#  99%|█████████▉| 12410/12475 [12:02<00:02, 25.40it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12410:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12411:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12412:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12413/12475 [12:02<00:02, 22.33it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12414:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12415:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12416:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12416/12475 [12:02<00:02, 23.32it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12413:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12417:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12421:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12419/12475 [12:02<00:02, 19.91it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12420:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12418:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12419:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12422:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12423:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12424/12475 [12:03<00:02, 23.28it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12424:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12427:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12426:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12427/12475 [12:03<00:02, 21.77it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12425:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12428:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12430:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12430/12475 [12:03<00:02, 20.91it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12429:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12431:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12433:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12433/12475 [12:03<00:02, 20.95it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12435:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12434:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12432:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12436/12475 [12:03<00:01, 21.22it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12437:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12436:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12440:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12439:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12438:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12441:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12442/12475 [12:03<00:01, 29.06it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12442:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12443:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12445:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12446:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12446/12475 [12:04<00:01, 24.57it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12444:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12448:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12447:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12449/12475 [12:04<00:01, 22.89it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12449:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12450:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12452:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12452/12475 [12:04<00:01, 19.50it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12454:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12451:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12453:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12455/12475 [12:04<00:00, 20.92it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12455:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12456:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12458:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12458/12475 [12:04<00:00, 22.07it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12457:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12462:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12459:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12461/12475 [12:04<00:00, 21.34it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12461:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12460:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12465:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12464/12475 [12:04<00:00, 20.10it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12463:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12464:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12466:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12467:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12468/12475 [12:05<00:00, 23.47it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12469:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12468:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12470:
#   warnings.warn(f"error for {i}: {e}")
# 100%|█████████▉| 12471/12475 [12:05<00:00, 23.31it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12473:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12472:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12471:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 12474:
#   warnings.warn(f"error for {i}: {e}")
# 100%|██████████| 12475/12475 [12:05<00:00, 17.20it/s]

# %%
error_list, len(error_list)
links[8]
# Out:
# 'https://www.yachtworld.com/yacht/1990-catalina-42-mk-i-3-sr-8617140/'

# %%
with ThreadPoolExecutor(max_workers=32) as t:
    tasks = [t.submit(set_data, k) for k in error_list.keys()]
    # tasks = [t.submit(set_data, i) for i in np.random.choice(len(links), 64, replace=False)]
    # tasks = [t.submit(set_data, i) for i in range(64)]
    for future in tqdm(as_completed(tasks), total=len(tasks)):
        pass
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 5077:
#   warnings.warn(f"error for {i}: {e}")
#   6%|▌         | 1/18 [00:04<01:10,  4.16s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 8257:
#   warnings.warn(f"error for {i}: {e}")
#  11%|█         | 2/18 [00:04<00:29,  1.84s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 11679:
#   warnings.warn(f"error for {i}: {e}")
#  17%|█▋        | 3/18 [00:04<00:19,  1.28s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 1945:
#   warnings.warn(f"error for {i}: {e}")
#  22%|██▏       | 4/18 [00:05<00:11,  1.23it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 4700:
#   warnings.warn(f"error for {i}: {e}")
#  28%|██▊       | 5/18 [00:05<00:07,  1.64it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 432:
#   warnings.warn(f"error for {i}: {e}")
#  33%|███▎      | 6/18 [00:05<00:05,  2.10it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 491:
#   warnings.warn(f"error for {i}: {e}")
#  39%|███▉      | 7/18 [00:06<00:05,  2.02it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 8:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 10914:
#   warnings.warn(f"error for {i}: {e}")
#  50%|█████     | 9/18 [00:06<00:02,  3.42it/s]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 468:
#   warnings.warn(f"error for {i}: {e}")
# C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3101:
#   warnings.warn(f"error for {i}: {e}")
#  61%|██████    | 11/18 [00:34<00:42,  6.04s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 8217:
#   warnings.warn(f"error for {i}: {e}")
#  67%|██████▋   | 12/18 [00:35<00:29,  4.87s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 7506:
#   warnings.warn(f"error for {i}: {e}")
#  72%|███████▏  | 13/18 [00:36<00:18,  3.79s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 8087:
#   warnings.warn(f"error for {i}: {e}")
#  78%|███████▊  | 14/18 [00:54<00:30,  7.63s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 9799:
#   warnings.warn(f"error for {i}: {e}")
#  83%|████████▎ | 15/18 [00:55<00:17,  5.68s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 1499:
#   warnings.warn(f"error for {i}: {e}")
#  89%|████████▉ | 16/18 [01:31<00:28, 14.02s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 3441:
#   warnings.warn(f"error for {i}: {e}")
#  94%|█████████▍| 17/18 [03:02<00:35, 35.96s/it]C:\Users\YeCanming\AppData\Local\Temp\ipykernel_3624\2863689197.py:18: UserWarning: error for 5309:
#   warnings.warn(f"error for {i}: {e}")
# 100%|██████████| 18/18 [03:02<00:00, 10.13s/it]

# %%
import pickle
with open('data.pickle', 'wb') as f:
    pickle.dump({"error_list":error_list, "yacht_data_list":yacht_data_list}, f)

# %%
with open('data.pickle', 'wb') as f:
    data = pickle.load(f)
    error_list = data['error_list']
    yacht_data_list = data['yacht_data_list']
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[43], line 2
#       1 with open('data.pickle', 'wb') as f:
# ----> 2     data = pickle.load(f)
#       3     error_list = data['error_list']
#       4     yacht_data_list = data['yacht_data_list']
#
# UnsupportedOperation: read

# %%
yacht_data_list[9]
yacht_data_list[8]
# Out:
# 8

# %%
final_yacht_data_list = list(filter(lambda x: not isinstance(x, int), yacht_data_list))
len(final_yacht_data_list)
# Out:
# 12457

# %%
error_list.keys()
len(error_list)
# Out:
# 18

# %%
links_table.index[list(error_list.keys())]
len(links_table.index[list(error_list.keys())])
# Out:
# 18

# %%
links_table.index.unique()
# Out:
# RangeIndex(start=0, stop=12475, step=1)

# %%
links_table = links_table.reset_index(drop=True)

# %%
links_table_new = links_table.drop(links_table.index[list(error_list.keys())])
len(links_table)-len(links_table_new)
len(links_table),len(links_table_new)
# Out:
# (12475, 12457)

# %%
df = pd.DataFrame(final_yacht_data_list)
df.head()
# Out:
#   Basics.Year Basics.Make Basics.Model   Basics.Class Basics.Length  \
# 0        2023    Jeanneau          380        Cruiser          38ft
# 1        2023      Dufour           37  Racer/Cruiser       35.33ft
# 2        2023     Bavaria          C42  Racer/Cruiser          42ft
# 3        1984       Union      Polaris         Cutter          36ft
# 4        2023      Dufour          470  Racer/Cruiser       48.75ft
#
#   Basics.FuelType Basics.HullMaterial Basics.HullShape Basics.HullWarranty  \
# 0          Diesel          Fiberglass         Monohull             7 years
# 1          Diesel          Fiberglass              NaN                 NaN
# 2          Diesel          Fiberglass              NaN                 NaN
# 3          Diesel          Fiberglass              NaN                 NaN
# 4          Diesel          Fiberglass              NaN                 NaN
#
#                 Basics.OfferedBy  ... Features.InsideEquipment.Seakeeper  \
# 0   Marine Servicenter - Seattle  ...                                NaN
# 1  Racine Riverside Marine, Inc.  ...                                NaN
# 2    Cruising Yachts - San Diego  ...                                NaN
# 3                 Rubicon Yachts  ...                                NaN
# 4  Racine Riverside Marine, Inc.  ...                                NaN
#
#   Features.InsideEquipment.AirCompressor Specifications.Speed&Distance.Range  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
#
#   Features.OutsideEquipment.WindGenerator Specifications.Dimensions.Freeboard  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   Specifications.Miscellaneous.LiferaftCapacity Propulsion.RopeCutter  \
# 0                                           NaN                   NaN
# 1                                           NaN                   NaN
# 2                                           NaN                   NaN
# 3                                           NaN                   NaN
# 4                                           NaN                   NaN
#
#   Specifications.Miscellaneous.DeadriseAtTransom  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Features.AdditionalEquipment.LaunchingTrailer  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Features.AdditionalEquipment.BeachingLegs
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 124 columns]

# %%
links_table=links_table.rename(columns={'Price':'Price-1'})

# %%
links_table_new.shape, df.shape
# Out:
# ((12457, 4), (12457, 124))

# %%
df.index, links_table_new.index
# Out:
# (RangeIndex(start=0, stop=12457, step=1),
#  Int64Index([    0,     1,     2,     3,     4,     5,     6,     7,     9,
#                 10,
#              ...
#              12465, 12466, 12467, 12468, 12469, 12470, 12471, 12472, 12473,
#              12474],
#             dtype='int64', length=12457))

# %%
links_table_new = links_table_new.reset_index(drop=True)

# %%
links_table_new.columns
# Out:
# Index(['Link', 'Price-1', 'Basics.Location', 'New'], dtype='object')

# %%
df = df.reset_index(drop=True)

# %%
total = pd.concat([links_table_new, df], axis=1)
total.shape
# Out:
# (12457, 128)

# %%
# (total['Price']-total['Price-1']).sum()/len(total)
# ((total['Price']-total['Price-1'])**2).sum()/len(total)
# (total['Price']==total['Price-1']).sum()/len(total)
((total['Price']-total['Price-1'])<1000).sum()/len(total)
# Out:
# 0.8225897085975756

# %%
total.to_excel('../../data/包含区域信息.xlsx')
